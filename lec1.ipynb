# %%
import matplotlib.pyplot as plt

m = 20
g = 9.8
c = 0.01
V = 0
t = 0
dt = 2

# Lists to store values for plotting
time_values = []
velocity_values = []

for i in range(20):
    print(f"V{t}={V}")
    time_values.append(t)
    velocity_values.append(V)

    V = V + (g - (c/m)*V) * dt
    t = t + dt

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(time_values, velocity_values, marker='o', linewidth=2, markersize=5)
plt.xlabel('Time (s)', fontsize=12)
plt.ylabel('Velocity (m/s)', fontsize=12)
plt.title('Velocity vs Time', fontsize=14)
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# V0=0
# V2=19.6
# V4=39.180400000000006
# V6=58.74121960000001
# V8=78.28247838040001
# V10=97.80419590201961
# V12=117.3063917061176
# V14=136.78908531441147
# V16=156.25229622909706
# V18=175.69604393286795
# V20=195.1203478889351
# V22=214.52522754104618
# V24=233.91070231350514
# V26=253.27679161119164
# V28=272.62351481958046
# V30=291.9508913047609
# V32=311.2589404134561
# V34=330.54768147304264
# V36=349.81713379156963
# V38=369.06731665777806
